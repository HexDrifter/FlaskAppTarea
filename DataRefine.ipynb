# %%
import pandas as pd

# %%
df = pd.read_csv("Hostel.csv")

# %%
df = df.drop("Unnamed: 0", axis=1)

# %%
df
# Out:
#                       hostel.name          City  price.from  \
# 0    "Bike & Bed" CharinCo Hostel         Osaka        3300
# 1                    & And Hostel  Fukuoka-City        2600
# 2           &And Hostel Akihabara         Tokyo        3600
# 3                &And Hostel Ueno         Tokyo        2600
# 4      &And Hostel-Asakusa North-         Tokyo        1500
# ..                            ...           ...         ...
# 337       YADOYA Guesthouse Green         Tokyo        2300
# 338      YADOYA Guesthouse Orange         Tokyo        2000
# 339             YAWP! backpackers         Tokyo        2500
# 340               You En Me House         Kyoto        2800
# 341               Zabutton Hostel         Tokyo        2900
#
#                     Distance  summary.score rating.band  atmosphere  \
# 0     2.9km from city centre            9.2      Superb         8.9
# 1     0.7km from city centre            9.5      Superb         9.4
# ...

# %%
df.to_json('Hostel.json', orient='records')

# %%
df = pd.read_json('data/Hostel.json', orient='split')

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 342 entries, 0 to 341
# Data columns (total 15 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   hostel.name    342 non-null    object
#  1   City           342 non-null    object
#  2   price.from     342 non-null    int64
#  3   Distance       342 non-null    object
#  4   summary.score  327 non-null    float64
#  5   rating.band    327 non-null    object
#  6   atmosphere     327 non-null    float64
#  7   cleanliness    327 non-null    float64
#  8   facilities     327 non-null    float64
#  9   location.y     327 non-null    float64
#  10  security       327 non-null    float64
#  11  staff          327 non-null    float64
#  12  valueformoney  327 non-null    float64
#  13  lon            298 non-null    float64
#  14  lat            298 non-null    float64
# dtypes: float64(10), int64(1), object(4)
# memory usage: 40.2+ KB

# %%
df = df.drop(["lon", 'lat','location.y' , 'valueformoney'], axis=1)

# %%
df['Distance']=df['Distance'].str.replace('km from city centre', '')

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 342 entries, 0 to 341
# Data columns (total 11 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   hostel.name    342 non-null    object
#  1   City           342 non-null    object
#  2   price.from     342 non-null    int64
#  3   Distance       342 non-null    object
#  4   summary.score  327 non-null    float64
#  5   rating.band    327 non-null    object
#  6   atmosphere     327 non-null    float64
#  7   cleanliness    327 non-null    float64
#  8   facilities     327 non-null    float64
#  9   security       327 non-null    float64
#  10  staff          327 non-null    float64
# dtypes: float64(6), int64(1), object(4)
# memory usage: 29.5+ KB

# %%
df['Distance'] = df['Distance'].astype(float)

# %%
df['rating.band'].unique()
# Out:
# array(['Superb', 'Fabulous', 'Very Good', nan, 'Rating', 'Good'],
#       dtype=object)

# %%
df = df.dropna()

# %%
df[df['rating.band']=='Rating']
# Out:
#                         hostel.name   City  price.from  Distance  \
# 34             bnb+ Ninja Dojo Ueno  Tokyo        2500       8.0
# 35              bnb+Shinjuku Castle  Tokyo        2500       1.3
# 67                     Ezstay Osaka  Osaka        2000       4.6
# 140                Hostel Ginkakuji  Kyoto        1300       2.7
# 234               Nagomi-Ryokan Yuu  Kyoto        3100       2.2
# 272                    Qoo Ebisucho  Osaka        2000       5.5
# 280              Sakura Guest House  Osaka        2700       4.3
# 290  Shibamata FU-TEN Bed and Local  Tokyo        3000      18.5
#
#      summary.score rating.band  atmosphere  cleanliness  facilities  security  \
# 34             5.2      Rating         4.0          3.3         4.0       5.3
# 35             5.0      Rating         2.7          4.0         3.3       5.3
# 67             3.1      Rating         2.0          2.0         2.0       6.0
# ...

# %%
df.columns
# Out:
# Index(['hostel.name', 'City', 'price.from', 'Distance', 'summary.score',
#        'rating.band', 'atmosphere', 'cleanliness', 'facilities', 'security',
#        'staff'],
#       dtype='object')

# %%
df.columns = ['Nombre_Hostal','Ciudad','Precio_desde','Distancia', 'Puntuacion_resumida', 'Rating', 'Atmosfera','Limpieza','Facilidades','Seguridad','Staff']

# %%
df.columns
# Out:
# Index(['Nombre_Hostal', 'Ciudad', 'Precio_desde', 'Distancia',
#        'Puntuacion_resumida', 'Rating', 'Atmosfera', 'Limpieza', 'Facilidades',
#        'Seguridad', 'Staff'],
#       dtype='object')

# %%
df.to_json('Hostel.json', orient='records',index=False, lines=True)
